# %%
import pandas as pd

# Assuming df1 and df2 are your two data frames
df1=pd.read_csv("/Users/dhikshitha./Desktop/Item Categorizer/Cleaned_Indian_Food_Dataset.csv")
df2=pd.read_csv("/Users/dhikshitha./Desktop/Item Categorizer/Final_Dataset - Sheet1.csv")
# Perform an equi-join based on the "Item Name" column
merged_df = pd.merge(df1, df2, on='Item Name', how='inner')

# 'inner' indicates that only matching rows will be included in the result

# merged_df will contain the merged data based on the common "Item Name" column

# %%
len(merged_df)
# Out:
# 3089

# %%
merged_df.head()
# Out:
#                                     Item Name  \
# 0                        Masala Karela Recipe
# 1                  Spicy Tomato Rice (Recipe)
# 2  Udupi Style Ash Gourd Coconut Curry Recipe
# 3     Mexican Style Black Bean Burrito Recipe
# 4            Spicy Crunchy Masala Idli Recipe
#
#                                TranslatedIngredients  TotalTimeInMins  \
# 0  1 tablespoon Red Chilli powder,3 tablespoon Gr...               45
# 1   2 teaspoon cashew - or peanuts, 1/2 Teaspoon ...               15
# 2  4 Dry Red Chillies,1/2 teaspoon Turmeric powde...               40
# 3  6 to 8 Spinach Leaves (Palak),1/4 cup Black be...               40
# 4  Mint Leaves (Pudina) - to taste,1/2 teaspoon T...               30
#
#               Cuisine_x                             TranslatedInstructions  \
# 0                Indian  To begin making the Masala Karela Recipe,de-se...
# 1  South Indian Recipes  To make tomato puliogere, first cut the tomato...
# ...

# %%
merged_df.to_csv("/Users/dhikshitha./Desktop/Item Categorizer/Food_Category.csv")
